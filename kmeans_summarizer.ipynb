# %%
from langchain_ollama import ChatOllama
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader
from langchain.chains.summarize import load_summarize_chain
from langchain.document_transformers import EmbeddingsClusteringFilter
from langchain.embeddings import HuggingFaceBgeEmbeddings

# %%
def extract(file_path):
    loader = PyPDFLoader(file_path)
    pages = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = 2000,
        chunk_overlap = 0
        )
    texts = text_splitter.split_documents(pages)
    return texts

# %%
def summarize_document_with_kmeans_clustering(file, llm, embeddings):
    filter = EmbeddingsClusteringFilter(embeddings = embeddings, num_clusters = 10)
    texts = extract(file)
    try:
        result = filter.transform_documents(documents = texts)
        checker_chain = load_summarize_chain(llm, chain_type = "stuff")
        summary = checker_chain.run(result)
        return summary
    except Exception as e:
        return str(e)

# %%
model_name = "BAAI/bge-base-en-v1.5"
model_kwargs = {"device": "cpu"} # Replace with "cuda" for GPU support
encode_kwargs = {"normalize_embeddings": True}

# %%
embeddings = HuggingFaceBgeEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)
# Out:
# C:\Users\kuchh\AppData\Local\Temp\ipykernel_18356\562469459.py:1: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceBgeEmbeddings(

# %%
llm = ChatOllama(
    model = "gemma3:1b", # Replace with LLM of your choice
    temperature = 0.25
)

# %%
print(summarize_document_with_kmeans_clustering("ibm.pdf", llm, embeddings))
# Out:
# C:\Users\kuchh\AppData\Local\Temp\ipykernel_18356\149810302.py:7: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   summary = checker_chain.run(result)
# Okay, let's break down this financial statement data. Here’s a summary of the key takeaways, organized for clarity:
#
# **1. Financial Performance - 2019:**
#
# *   **Revenue:** The company’s revenue for 2019 was $1,319 million.
# *   **Profitability:** The company’s profit margin for 2019 was 14%.
# *   **Pension Liabilities:** Pension liabilities were $1,284 million.
# *   **Deferred Revenue:** The company’s deferred revenue for 2019 was $2,072 million.
#
# **2.  Pension Plan Details – 2019:**
#
# *   **Defined Benefit Pension Plans:**  The company has 803 million dollars in defined benefit pension plans.
# *   **Non-Defined Benefit Pension Plans:** 11 million dollars in non-defined benefit pension plans.
# *   **Total Defined Benefit Pension Plans:** 955 million dollars.
# *   **Retention Plan:** 11 million dollars in retention plan.
# *   **Total Defined Benefit Pension Plans:** 1178 million dollars.
#
# **3.  401(k) Plus Plan & Non-U.S. Plans:**
#
# *   **Defined Contribution Plans:** 585 million dollars in defined contribution plans.
# *   **Total Defined Contribution Plans:** 612 million dollars.
#
# **4.  Excess 401(k) and Total Retirement Benefits:**
#
# *   **Excess 401(k):** 27 million dollars.
# *   **Total Retirement Benefits:** 934 million dollars.
#
# **5.  Key Trends & Observations:**
#
# *   **Revenue Growth:** Revenue increased from $1,319 million in 2019 to $1,355 million in 2019.
# *   **Pension Liabilities:** Pension liabilities have been increasing over time, showing a consistent trend.
# *   **Retention Plan:** The retention plan is a significant component of the company's pension plan.
# *   **Excess 401(k):** The excess 401(k) is a notable figure, indicating a potential surplus in the plan.
#
# **6.  Important Notes:**
#
# *   **Deferred Revenue:** The company has a substantial amount of deferred revenue, which is a key indicator of long-term revenue potential.
# *   **Pension Plan Assumptions:** The company is relying on current pension plan assumptions.
#
# **In essence, the statement paints a picture of a company with a growing revenue base, a substantial pension liability, and a significant amount of deferred revenue, with a focus on maintaining its pension plan.**
#
# Do you want me to elaborate on any specific aspect of this data, such as a deeper dive into a particular segment (like pension liabilities)?
